# %%
from pylab import *

# %%
r = linspace(0, 1)
th = linspace(0, 2*pi)
i = 1j
z = r*exp(th*i)
plt.plot(real(z), imag(z))
axis('equal');

# %%
r = linspace(0, 1, 1000)
th = linspace(0, 10*pi, 1000)
i = 1j
z = r*exp(th*i)
plt.plot(real(z), imag(z))
axis('equal');

# %%
sin(i)
# Out:
# 1.1752011936438014j
