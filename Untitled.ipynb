# %%
# %pylab inline
r = 1
n = 75
k = arange(0, n)
z = r*exp(1j*2*pi*k/n)
plot(real(z), imag(z), '.')
title('$\lambda^{75} = 1$')
xlabel('Real')
ylabel('Imag')
grid(True)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
real(1j)
# Out:
# 0.0
